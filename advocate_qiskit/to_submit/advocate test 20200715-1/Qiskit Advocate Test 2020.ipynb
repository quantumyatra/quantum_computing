# %% [markdown]
# # Instructions
# This is the Qiskit Advocate Test notebook. You will need to write and execute Qiskit code to answer several questions in this test. Once you have answered all the questions, you will need to submit the test for grading. You will be informed via email of you application outcome shortly after the end of application period.
#
# **This notebook only runs correctly using Jupyter notebook. It is currently incompatible with Jupyter lab.**
#
# In order to use this notebook, please follow these instructions.
# 1. Run the cell below to install any dependencies of this notebook including `qiskit`, `metakernel`, `portalocker` and `matplotlib`. Make sure you install Qiskit version `0.19.6` for the test.
# 1. Fill out your name in the `Personal Information` section below and run that cell. Make sure you get the output `Done`.
# 1. To see the questions for each section, run the line that looks like `%activity questions/section`. You can go back and forth and select different answers.
# 1. There are **30 questions** throughout this test. Your answers to each question are stored as soon as you select a choice, and are not erased if you re-start a section of questions.
# 1. You can change your answers as many times as you'd like. All answers will be stored but **only the last answer will be graded**.
# 1. To submit your answers, run the `Submit` cell. This will generate a file named `answers_yourname.zip`. Please attach this file to the advocate application form.
#
# The primary reference materials for the test are [Qiskit Tutorials](https://qiskit.org/documentation/tutorials/circuits/index.html) and [Qiskit Documentation](https://qiskit.org/documentation/). In addtion, [Qiskit Textbook](https://qiskit.org/textbook/preface.html), [Coding with Qiskit](https://www.youtube.com/playlist?list=PLOFEBzvs-Vvp2xg9-POLJhQwtVktlYGbY), [Qiskit Live Circuit Sessions](https://www.youtube.com/playlist?list=PLOFEBzvs-VvrRlVz7wqaqmaMZj_ZK2Afe) and [1 Minute Qiskit](https://www.youtube.com/playlist?list=PLOFEBzvs-VvpOCmJ9BonUhf7NYB4d1p0e) are also good source of reference. If you have any questions please reach out in the `qiskit-advocates-help` channel on Qiskit Slack.

# %%
# install dependencies
# !pip3 install --upgrade qiskit==0.19.6 
# !pip3 install --upgrade metakernel
# !pip3 install --upgrade portalocker
# !pip3 install --upgrade matplotlib
# Out:
# Requirement already up-to-date: qiskit==0.19.6 in /Users/gshyam/Library/Python/3.8/lib/python/site-packages (0.19.6)
# Requirement already satisfied, skipping upgrade: qiskit-terra==0.14.2 in /usr/local/lib/python3.8/site-packages (from qiskit==0.19.6) (0.14.2)
# Requirement already satisfied, skipping upgrade: qiskit-aqua==0.7.3 in /usr/local/lib/python3.8/site-packages (from qiskit==0.19.6) (0.7.3)
# Requirement already satisfied, skipping upgrade: qiskit-ignis==0.3.3 in /usr/local/lib/python3.8/site-packages (from qiskit==0.19.6) (0.3.3)
# Requirement already satisfied, skipping upgrade: qiskit-ibmq-provider==0.7.2 in /usr/local/lib/python3.8/site-packages (from qiskit==0.19.6) (0.7.2)
# Requirement already satisfied, skipping upgrade: qiskit-aer==0.5.2 in /Users/gshyam/Library/Python/3.8/lib/python/site-packages (from qiskit==0.19.6) (0.5.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (1.19.0)
# Requirement already satisfied, skipping upgrade: marshmallow-polyfield<6,>=5.7 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (5.9)
# Requirement already satisfied, skipping upgrade: jsonschema>=2.6 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (3.2.0)
# Requirement already satisfied, skipping upgrade: retworkx>=0.3.2 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (0.3.4)
# Requirement already satisfied, skipping upgrade: sympy>=1.3 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (1.6.1)
# Requirement already satisfied, skipping upgrade: dill>=0.3 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (0.3.2)
# Requirement already satisfied, skipping upgrade: fastjsonschema>=2.10 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (2.14.4)
# Requirement already satisfied, skipping upgrade: python-constraint>=1.4 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (1.4.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.0 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (2.8.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.4 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (1.4.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.2; python_version > "3.5" in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (2.4)
# Requirement already satisfied, skipping upgrade: psutil>=5 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (5.7.2)
# Requirement already satisfied, skipping upgrade: marshmallow<4,>=3 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (3.7.0)
# Requirement already satisfied, skipping upgrade: ply>=3.10 in /usr/local/lib/python3.8/site-packages (from qiskit-terra==0.14.2->qiskit==0.19.6) (3.11)
# Requirement already satisfied, skipping upgrade: pyscf; sys_platform != "win32" in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (1.7.3)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (2.10.0)
# Requirement already satisfied, skipping upgrade: quandl in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (3.5.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.1.0 in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (49.2.0)
# Requirement already satisfied, skipping upgrade: docplex in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (2.15.194)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (0.23.1)
# Requirement already satisfied, skipping upgrade: dlx in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (1.0.4)
# Requirement already satisfied, skipping upgrade: fastdtw in /usr/local/lib/python3.8/site-packages (from qiskit-aqua==0.7.3->qiskit==0.19.6) (0.3.4)
# Requirement already satisfied, skipping upgrade: urllib3>=1.21.1 in /usr/local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (1.25.9)
# Requirement already satisfied, skipping upgrade: nest-asyncio!=1.1.0,>=1.0.0 in /usr/local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (1.3.3)
# Requirement already satisfied, skipping upgrade: websockets<8,>=7 in /usr/local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (7.0)
# Requirement already satisfied, skipping upgrade: requests>=2.19 in /usr/local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (2.24.0)
# Requirement already satisfied, skipping upgrade: requests-ntlm>=1.1.0 in /usr/local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (1.1.0)
# Requirement already satisfied, skipping upgrade: pybind11>=2.4 in /usr/local/lib/python3.8/site-packages (from qiskit-aer==0.5.2->qiskit==0.19.6) (2.5.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.1 in /usr/local/lib/python3.8/site-packages (from qiskit-aer==0.5.2->qiskit==0.19.6) (0.29.21)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /usr/local/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.14.2->qiskit==0.19.6) (0.16.0)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in /usr/local/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.14.2->qiskit==0.19.6) (1.15.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /usr/local/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.14.2->qiskit==0.19.6) (19.3.0)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /usr/local/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra==0.14.2->qiskit==0.19.6) (1.1.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.8/site-packages (from networkx>=2.2; python_version > "3.5"->qiskit-terra==0.14.2->qiskit==0.19.6) (4.4.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.14 in /usr/local/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.7.3->qiskit==0.19.6) (1.0.5)
# Requirement already satisfied, skipping upgrade: inflection>=0.3.1 in /usr/local/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.7.3->qiskit==0.19.6) (0.5.0)
# Requirement already satisfied, skipping upgrade: more-itertools in /usr/local/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.7.3->qiskit==0.19.6) (8.4.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.7.3->qiskit==0.19.6) (0.16.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.7.3->qiskit==0.19.6) (2.1.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (3.0.4)
# Requirement already satisfied, skipping upgrade: cryptography>=1.3 in /usr/local/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (2.9.2)
# Requirement already satisfied, skipping upgrade: ntlm-auth>=1.0.2 in /usr/local/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (1.5.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.8/site-packages (from pandas>=0.14->quandl->qiskit-aqua==0.7.3->qiskit==0.19.6) (2020.1)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.8/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (1.14.0)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit==0.19.6) (2.20)
# Requirement already up-to-date: metakernel in /usr/local/lib/python3.8/site-packages (0.24.4)
# Requirement already satisfied, skipping upgrade: pexpect>=4.2 in /usr/local/lib/python3.8/site-packages (from metakernel) (4.8.0)
# Requirement already satisfied, skipping upgrade: ipykernel in /usr/local/lib/python3.8/site-packages (from metakernel) (5.3.2)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /usr/local/lib/python3.8/site-packages (from pexpect>=4.2->metakernel) (0.6.0)
# Requirement already satisfied, skipping upgrade: ipython>=5.0.0 in /usr/local/lib/python3.8/site-packages (from ipykernel->metakernel) (7.16.1)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in /usr/local/lib/python3.8/site-packages (from ipykernel->metakernel) (6.0.4)
# Requirement already satisfied, skipping upgrade: appnope; platform_system == "Darwin" in /usr/local/lib/python3.8/site-packages (from ipykernel->metakernel) (0.1.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.1.0 in /usr/local/lib/python3.8/site-packages (from ipykernel->metakernel) (4.3.3)
# Requirement already satisfied, skipping upgrade: jupyter-client in /usr/local/lib/python3.8/site-packages (from ipykernel->metakernel) (6.1.6)
# Requirement already satisfied, skipping upgrade: pygments in /usr/local/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->metakernel) (2.6.1)
# Requirement already satisfied, skipping upgrade: decorator in /usr/local/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->metakernel) (4.4.2)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->metakernel) (3.0.5)
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/local/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->metakernel) (0.7.5)
# Requirement already satisfied, skipping upgrade: backcall in /usr/local/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->metakernel) (0.2.0)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /usr/local/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->metakernel) (49.2.0)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /usr/local/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->metakernel) (0.17.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.8/site-packages (from traitlets>=4.1.0->ipykernel->metakernel) (1.15.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /usr/local/lib/python3.8/site-packages (from traitlets>=4.1.0->ipykernel->metakernel) (0.2.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in /usr/local/lib/python3.8/site-packages (from jupyter-client->ipykernel->metakernel) (19.0.1)
# Requirement already satisfied, skipping upgrade: jupyter-core>=4.6.0 in /usr/local/lib/python3.8/site-packages (from jupyter-client->ipykernel->metakernel) (4.6.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.8/site-packages (from jupyter-client->ipykernel->metakernel) (2.8.1)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->metakernel) (0.2.5)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in /usr/local/lib/python3.8/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->metakernel) (0.7.0)
# Requirement already up-to-date: portalocker in /usr/local/lib/python3.8/site-packages (2.0.0)
# Collecting matplotlib
#   Downloading matplotlib-3.3.1-cp38-cp38-macosx_10_9_x86_64.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 2.3 MB/s eta 0:00:01     |████                            | 1.1 MB 2.3 MB/s eta 0:00:04
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.8/site-packages (from matplotlib) (1.19.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /usr/local/lib/python3.8/site-packages (from matplotlib) (7.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in /usr/local/lib/python3.8/site-packages (from matplotlib) (2020.6.20)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /usr/local/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.8/site-packages (from python-dateutil>=2.1->matplotlib) (1.15.0)
# ERROR: fastai 0.7.0 requires bcolz, which is not installed.
# ERROR: fastai 0.7.0 requires feather-format, which is not installed.
# ERROR: fastai 0.7.0 requires html5lib, which is not installed.
# ERROR: fastai 0.7.0 requires isoweek, which is not installed.
# ERROR: fastai 0.7.0 requires jupyter, which is not installed.
# ERROR: fastai 0.7.0 requires plotnine, which is not installed.
# ERROR: fastai 0.7.0 requires simplegeneric, which is not installed.
# ERROR: fastai 0.7.0 requires sklearn-pandas, which is not installed.
# ERROR: fastai 0.7.0 requires torchtext, which is not installed.
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.5.1 which is incompatible.
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.3.0
#     Uninstalling matplotlib-3.3.0:
#       Successfully uninstalled matplotlib-3.3.0
# Successfully installed matplotlib-3.3.1

# %%
from metakernel import register_ipython_magics
register_ipython_magics()

from IPython.display import clear_output
clear_output()

import qiskit
version_info = qiskit.__qiskit_version__
print("You are now running Qiskit with the following version numbers")
print(version_info)
# Out:
# You are now running Qiskit with the following version numbers
# {'qiskit-terra': '0.14.2', 'qiskit-aer': '0.5.1', 'qiskit-ignis': '0.3.3', 'qiskit-ibmq-provider': '0.7.2', 'qiskit-aqua': '0.7.3', 'qiskit': '0.19.6'}

# %% [markdown]
# # Personal Information

# %%
your_name = "Ghanashyam Khanal" # insert your name here between the quotes

import os
try:
    assert(your_name != '')
    answer_dir = 'answers/'
    if not os.path.isdir(answer_dir):
        os.mkdir(answer_dir)
    open(answer_dir + 'taker_info.txt', 'w').write('name = {}\nversion_info = {}'.format(your_name, version_info))
    print('Done')
except:
    print("Error. Please reach out in the #qiskit-advocates-help on Qiskit Slack.")
# Out:
# Done

# %% [markdown]
# ---
# # Space for trying out answers
# You can add any new cells in this notebook to try to figure out the answers for questions.

# %%
# example
from qiskit import QuantumCircuit
qc = QuantumCircuit(1)
qc.h(0)
qc.draw('mpl')

# %%
# you can insert new cells like this by clicking the "+" button on the menu bar

# %% [markdown]
# ---
# # Contents <a name="toc"></a>
#
# 1. [Circuits (5 questions)](#circuits)
# 1. [Advanced Circuits (5 questions)](#advanced_circuits)
# 1. [Running on Real Devices (2 questions)](#real_devices)
# 1. [Pulse (5 questions)](#pulse)
# 1. [High-Performance Simulators (7 questions)](#simulators)
# 1. [Quantum System Error Analysis  (3 questions)](#error_analysis)
# 1. [Optimization (3 questions)](#optimization)

# %% [markdown]
# # Circuits (5 questions)<a name="circuits"></a>
# Reference:
# 1. [Qiskit Tutorials - Circuits](https://qiskit.org/documentation/tutorials/circuits/index.html)
# 1. [Qiskit Documentation - Terra](https://qiskit.org/documentation/apidoc/terra.html)
# 1. [Coding with Qiskit - Ep.3 Hello World](https://www.youtube.com/watch?v=RrUTwq5jKM4)
# 1. [Coding with Qiskit - Ep.4 Building Blocks of Quantum Circuits](https://www.youtube.com/watch?v=tBnWG_95F9c)

# %%
# %activity questions/circuits
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p><b>Question ID</b>: 1</p>'), HTML(value='<h1><h4>W…

# %% [markdown]
# # Advanced Circuits (5 questions)<a name="advanced_circuits"></a>
# Reference:
# 1. [Qiskit Tutorials - Advanced Circuits](https://qiskit.org/documentation/tutorials/circuits_advanced/index.html)
# 1. [Qiskit Documentation - Terra](https://qiskit.org/documentation/apidoc/terra.html)
# 1. [Circuit Sessions - Qiskit Circuit Library](https://www.youtube.com/watch?v=SsXJgAZ6aIg)
# 1. [Circuit Sessions - Transpiling Quantum Circuits](https://www.youtube.com/watch?v=2T3163VjvWQ)

# %%
# %activity questions/advanced_circuits
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p><b>Question ID</b>: 1</p>'), HTML(value='<h1>\n   …

# %% [markdown]
# # Running on Real Devices (2 questions)<a name="real_devices"></a>
# Reference:
# 1. [Qiskit Tutorials - The IBM Account](https://github.com/Qiskit/qiskit-tutorials/blob/master/legacy_tutorials/terra/3_the_ibmq_account.ipynb)
# 1. [Qiskit Documentation - IBM Quantum Provider](https://qiskit.org/documentation/apidoc/ibmq_provider.html)
# 1. [1 Minute Qiskit - How can I retrieve an old job from IBM Quantum?](https://www.youtube.com/watch?v=09-Qsge_qqo&list=PLOFEBzvs-VvpOCmJ9BonUhf7NYB4d1p0e&index=6)

# %%
# %activity questions/real_devices
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p><b>Question ID</b>: 1</p>'), HTML(value='<h1>\n   …

# %% [markdown]
# # Pulse (5 questions)<a name="pulse"></a>
# Reference:
# 1. [Qiskit Tutorials - Pulse](https://qiskit.org/documentation/tutorials/pulse/index.html)
# 1. [Qiskit Textbook - Ch.6.1 Calibrating Qubits with Qiskit Pulse](https://qiskit.org/textbook/ch-quantum-hardware/calibrating-qubits-openpulse.html)
# 1. [Qiskit Documentation - Pulse](https://qiskit.org/documentation/apidoc/pulse.html)
# 1. [Qiskit Live - Quantum Coding with Lauren Capelluto](https://www.youtube.com/watch?v=ZvipHRY-URs)

# %%
# %activity questions/pulse
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p><b>Question ID</b>: 1</p>'), HTML(value='<h1>\n   …

# %% [markdown]
# # High-Performance Simulators (7 questions)<a name="simulators"></a>
# Reference:
# 1. [Qiskit Tutorials - High-Performance Simulators](https://qiskit.org/documentation/tutorials/simulators/index.html)
# 1. [Qiskit Documentation - Aer](https://qiskit.org/documentation/apidoc/aer.html)
# 1. [Circuit Sessions - How to simulate a circuit](https://www.youtube.com/watch?v=VvP41TwY34o)

# %%
# %activity questions/simulators
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p><b>Question ID</b>: 1</p>'), HTML(value='<h1>\n   …

# %% [markdown]
# # Quantum System Error Analysis (3 questions)<a name="error_analysis"></a>
# Reference:
# 1. [Qiskit Tutorials - Quantum System Error Analysis](https://qiskit.org/documentation/tutorials/noise/index.html)
# 1. [Qiskit Documentation - Ignis](https://qiskit.org/documentation/apidoc/ignis.html)
# 1. [Coding with Qiskit - Ep.8 Mitigating Noise on Real Quantum Computers](https://www.youtube.com/watch?v=yuDxHJOKsVA)

# %%
# %activity questions/error_analysis
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p><b>Question ID</b>: 1</p>'), HTML(value='<h1>\n   …

# %% [markdown]
# # Optimization (3 questions)<a name="optimization"></a>
# Reference:
# 1. [Qiskit Tutorials - Optimization](https://qiskit.org/documentation/tutorials/optimization/index.html)
# 1. [Qiskit Documentation - Optimization](https://qiskit.org/documentation/apidoc/qiskit_optimization.html)
# 1. [Qiskit Medium - A Walkthrough of Qiskit’s New Optimization Module](https://medium.com/qiskit/towards-quantum-advantage-for-optimization-with-qiskit-9a564339ef26)

# %%
# %activity questions/optimization
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p><b>Question ID</b>: 1</p>'), HTML(value="<h1>\n   …

# %% [markdown]
# # Submit

# %%
from shutil import make_archive
try:
    assert(os.path.exists(answer_dir + 'circuits.results'))
    assert(os.path.exists(answer_dir + 'advanced_circuits.results'))
    assert(os.path.exists(answer_dir + 'real_devices.results'))
    assert(os.path.exists(answer_dir + 'pulse.results'))
    assert(os.path.exists(answer_dir + 'simulators.results'))
    assert(os.path.exists(answer_dir + 'error_analysis.results'))
    assert(os.path.exists(answer_dir + 'optimization.results'))
    assert(os.path.exists(answer_dir + 'taker_info.txt'))
    zipfilename = 'answers_{}'.format(your_name)
    make_archive(zipfilename, 'zip', answer_dir)
    print('Done. Please attach {}.zip to the application form for grading.'.format(zipfilename))
except:
    print("You have not completed all the sections. If you think this is in error, please contact us in the #qiskit-advocates-help channel on Qiskit Slack")
# Out:
# Done. Please attach answers_Ghanashyam Khanal.zip to the application form for grading.
